# %%
#Train model
from sklearn.model_selection import train_test_split
import os
import random

import tensorflow as tf
import cv2
import numpy as np
#Import Unet model from segmentation_models 
from segmentation_models.metrics import iou_score
from segmentation_models import Unet
import segmentation_models as sm

#Import lib for run wandb
import wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

sm.set_framework("tf.keras")
sm.framework()
# Out:
# Segmentation Models: using `keras` framework.
# 'tf.keras'

# %%
#Data loader
#Initializer parameters
data_folder = r"train\train"
label_folder = r"train_gt\train_gt"
BACKBONE = "resnet34"
preprocess_input = sm.get_preprocessing(BACKBONE)
batch_size = 16
w, h = 384, 384

# Load data follow batch_size and image_size
class Dataset:
    def __init__(self, image_path, mask_path, w, h):
        # the paths of images
        self.image_path = image_path
        # the paths of segmentation images
        self.mask_path = mask_path

        self.w = w
        self.h = h

    def __getitem__(self, i):
        # read data
        image = cv2.imread(self.image_path[i])
        image = cv2.resize(image, (self.w, self.h), interpolation=cv2.INTER_AREA)
        image = preprocess_input(image)

        mask = cv2.imread(self.mask_path[i], cv2.IMREAD_UNCHANGED)

        tmp = np.zeros_like(mask)
        tmp1 = np.where(mask[:,:, 1] > 200, 255, 0) + np.where(mask[:,:, 2] > 200, 255, 0)
        tmp[:,:, 0] = np.where(tmp1 > 50, 0, 255)
        tmp[:,:, 1] = np.where(mask[:, :, 1] > 200, 255, 0)
        tmp[:,:, 2] = np.where(mask[:, :, 2] > 200, 255, 0)

        image_mask = cv2.resize(tmp, (w, h), interpolation=cv2.INTER_AREA)
        
        #normalization
        mask_image = np.where(image_mask > 100, 1, 0)
        

        mask_image = [(mask_image == v) for v in [1]]
        mask_image = np.stack(mask_image, axis=-1).astype('float')

        return image, mask_image

class Dataloader(tf.keras.utils.Sequence):
    def __init__(self, dataset, batch_size,shape, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.shape = shape
        self.indexes = np.arange(self.shape)

    def __getitem__(self, i):
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])

        batch = [np.stack(samples, axis=0) for samples in zip(*data)]

        return tuple(batch)

    def __len__(self):
        return len(self.indexes) // self.batch_size

    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

#  Load data from folder dataset for create image_path, mask_path
def load_path(data_folder = data_folder):

    # Lay data_path va label_path tuong ung
    data_path = []
    label_path = []
    for file in os.listdir(data_folder):
        if (file.endswith("png") or file.endswith("jpeg")) and (not file.startswith(".")):
            image_path = os.path.join(data_folder, file)
            mask_path = os.path.join(label_folder, file)
            label_path.append(mask_path)
            data_path.append(image_path)

    return data_path, label_path

# Load path to variables
data_path, label_path = load_path()

#train test split
image_train, image_val, mask_train, mask_val = train_test_split(data_path, label_path, test_size = 0.25)

#Create data set and data loader
train_dataset = Dataset(image_train, mask_train, w, h)
val_dataset = Dataset(image_val, mask_val, w, h)

#Loader
train_loader = Dataloader(train_dataset, batch_size, shape = len(image_train), shuffle = True)
val_loader = Dataloader(val_dataset, batch_size, shape = len(image_val), shuffle = True)

# %%
Dataloader
# Out:
# __main__.Dataloader

# %%
#Initilize model
opt=tf.keras.optimizers.Adam(0.0001)
model= Unet(BACKBONE,encoder_weights = "imagenet",classes = 3,activation="softmax",input_shape = (384,384,3),encoder_freeze = False)
loss1 = sm.losses.categorical_focal_dice_loss

model.compile(optimizer=opt,loss=loss1,metrics=[iou_score])

# %%
#Check hardware
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU') 
for gpu in gpus: 
    print(gpu)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
epochs = 20
wandb.init(project = "Polyp_segmentation_unet_model(3)",
            config = {
                "learning_rate": "Adam(0.0001)",
                "epochs": epochs,
                "batch_size": batch_size,
                "loss_function": "categorical_focal_dice_loss",
                "architecture": "UNET"
            })

#Train model
from keras.callbacks import ModelCheckpoint

epochs = 30
filepath="checkpoint_2.hdf5"
callback = WandbModelCheckpoint(filepath, monitor='val_iou_score', verbose=1, save_best_only=True,mode='max')

model.fit( train_loader, validation_data=val_loader, epochs= epochs , callbacks=[WandbMetricsLogger(), callback])
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: tranvuongquocdat (you-know-who). Use `wandb login --relogin` to force relogin
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>c:\Users\PC\Desktop\TaiLieu\Computer vision lab\Polyp segmentation\wandb\run-20230313_121935-yowpnfhx</code>
# Syncing run <strong><a href="https://wandb.ai/you-know-who/Polyp_segmentation_unet_model%282%29/runs/yowpnfhx" target="_blank">lilac-energy-2</a></strong> to <a href="https://wandb.ai/you-know-who/Polyp_segmentation_unet_model%282%29" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING When using `save_best_only`, ensure that the `filepath` argument contains formatting placeholders like `{epoch:02d}` or `{batch:02d}`. This ensures correct interpretation of the logged artifacts.
# Epoch 1/20
# 359/421 [========================>.....] - ETA: 48s - loss: 0.7140 - iou_score: 0.2193
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\PC\Desktop\TaiLieu\Computer vision lab\Polyp segmentation\Data_Loader_and_Train - Copy.ipynb Cell 6 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/TaiLieu/Computer%20vision%20lab/Polyp%20segmentation/Data_Loader_and_Train%20-%20Copy.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> filepath="checkpoint_2.hdf5"
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/TaiLieu/Computer%20vision%20lab/Polyp%20segmentation/Data_Loader_and_Train%20-%20Copy.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> callback = WandbModelCheckpoint(filepath, monitor='val_iou_score', verbose=1, save_best_only=True,mode='max')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/TaiLieu/Computer%20vision%20lab/Polyp%20segmentation/Data_Loader_and_Train%20-%20Copy.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> model.fit( train_loader, validation_data=val_loader, epochs= epochs , callbacks=[WandbMetricsLogger(), callback])
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\wandb\integration\keras\keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\wandb\integration\keras\keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\wandb\integration\keras\keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:385, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     382 if self._check_timing:
#     383     start_time = time.time()
# --> 385 logs = self._process_logs(logs, is_batch_hook=True)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\callbacks.py:292, in CallbackList._process_logs(self, logs, is_batch_hook)
#     290 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     291     return logs
# --> 292 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
#model.save('best3.h5')

# %%
#Test with val data
model.load_weights("best3.hdf5")

ids = range(len(image_val))
index = random.sample(ids, 10)
w, h = 384, 384

import matplotlib.pyplot as plt

for id in index:

    # Input image
    image = cv2.imread(image_val[id])
    image = cv2.resize(image, (w, h))
    # Predict segmentation map with trained model

    mask_predict = model.predict(image[np.newaxis, :, :, :])

    # Read real mask
    image_mask = cv2.imread(mask_val[id], cv2.IMREAD_UNCHANGED)
    image_mask = cv2.resize(image_mask, (w, h))

    plt.figure(figsize=(10, 6))
    plt.subplot(131)
    plt.title("Image")
    plt.imshow(image)
    plt.subplot(132)
    plt.title("Real Polyp")
    plt.imshow(image_mask)
    plt.subplot(133)
    plt.title("Predicted Polyp")
    z = mask_predict[0]#[:, :, 1:2]
    plt.imshow(z)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
#Test with test data
import matplotlib.pyplot as plt
import random

model.load_weights("checkpoint_2.hdf5")

#Test with images in test folder
test_folder = "test/test"
count = 0
num_images = 3
w, h = 384, 384

while count <= num_images:
    file = random.choice(os.listdir(test_folder))
    count += 1
    # Input image
    image_path = os.path.join(test_folder, file)
    image = cv2.imread(image_path)
    image = cv2.resize(image, (w, h))
    # Predict segmentation map with trained model

    mask_predict = model.predict(image[np.newaxis, :, :, :])

    plt.figure(figsize=(10, 6))
    plt.subplot(131)
    plt.title("Image")
    plt.imshow(image)
    plt.subplot(132)
    plt.title("Predicted Neo Polyp")
    z = mask_predict[0]#[:, :, 1]
    plt.imshow(z)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
